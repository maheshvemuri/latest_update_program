# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\MAHESH\Downloads\bank.csv"
bank_df=pd.read_csv(path,sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
cat_columns=bank_df.select_dtypes(include='object').columns
num_columns=bank_df.select_dtypes(exclude='object').columns

# %%
cat_columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
num_columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
import os
root_directory=os.getcwd()
root_directory
new_directory='value_counts_df'
new_directory
new_df1=os.path.join(root_directory,new_directory)
new_df1
# Out:
# 'C:\\Users\\MAHESH\\Documents\\eda\\value_counts_df'

# %%
import seaborn as sns
for i in cat_columns[1:]:
    plt.figure(figsize=(8,5))
    order_continents=bank_df[i].value_counts().keys()
    sns.countplot(data=bank_df,x=i,order=order_continents)
    plt.title("bar chart")
    plt.savefig(f"{new_df1}\{i}_value_counts_df.jpg")
    plt.show()
# Out:
# <string>:7: SyntaxWarning: invalid escape sequence '\{'
# <>:7: SyntaxWarning: invalid escape sequence '\{'
# <string>:7: SyntaxWarning: invalid escape sequence '\{'
# <>:7: SyntaxWarning: invalid escape sequence '\{'
# C:\Users\MAHESH\AppData\Local\Temp\ipykernel_10544\3760247306.py:7: SyntaxWarning: invalid escape sequence '\{'
#   plt.savefig(f"{new_df1}\{i}_value_counts_df.jpg")

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'assignment-4.ipynb',
#  'bank data.ipynb',
#  'case_id.csv',
#  'case_status.csv',
#  'case_status_df.csv',
#  'case_status_seaborn.png',
#  'categorical_data_analysis.ipynb',
#  'continent.csv',
#  'continents_df.csv',
#  'continents_seaborn.png',
#  'continent_df.csv',
#  'Data1.xlsx',
#  'education_df.csv',
#  'education_of_employee.csv',
#  'full_time_position.csv',
#  'graphs_matplotlib',
#  'graphs_seaborn',
#  'has_job_experience.csv',
#  'region_of_employment.csv',
#  'requires_job_training.csv',
#  'unit_of_wage.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'value_counts_df']

# %%
cdf=os.listdir(new_df1)
cdf
# Out:
# ['contact bank_graphs_seaborn.jpg',
#  'contact_bank_graphs_seaborn.jpg',
#  'default bank_graphs_seaborn.jpg',
#  'default_bank_graphs_seaborn.jpg',
#  'education bank_graphs_seaborn.jpg',
#  'education_bank_graphs_seaborn.jpg',
#  'housing bank_graphs_seaborn.jpg',
#  'housing_bank_graphs_seaborn.jpg',
#  'loan bank_graphs_seaborn.jpg',
#  'loan_bank_graphs_seaborn.jpg',
#  'marital bank_graphs_seaborn.jpg',
#  'marital_bank_graphs_seaborn.jpg',
#  'month bank_graphs_seaborn.jpg',
#  'month_bank_graphs_seaborn.jpg',
#  'poutcome bank_graphs_seaborn.jpg',
#  'poutcome_bank_graphs_seaborn.jpg',
#  'y bank_graphs_seaborn.jpg',
#  'y_bank_graphs_seaborn.jpg']

# %%
for i in cdf:
    print(i)
# Out:
# contact bank_graphs_seaborn.jpg
# contact_bank_graphs_seaborn.jpg
# default bank_graphs_seaborn.jpg
# default_bank_graphs_seaborn.jpg
# education bank_graphs_seaborn.jpg
# education_bank_graphs_seaborn.jpg
# housing bank_graphs_seaborn.jpg
# housing_bank_graphs_seaborn.jpg
# loan bank_graphs_seaborn.jpg
# loan_bank_graphs_seaborn.jpg
# marital bank_graphs_seaborn.jpg
# marital_bank_graphs_seaborn.jpg
# month bank_graphs_seaborn.jpg
# month_bank_graphs_seaborn.jpg
# poutcome bank_graphs_seaborn.jpg
# poutcome_bank_graphs_seaborn.jpg
# y bank_graphs_seaborn.jpg
# y_bank_graphs_seaborn.jpg

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'assignment-4.ipynb',
#  'bank data.ipynb',
#  'case_id.csv',
#  'case_status.csv',
#  'case_status_df.csv',
#  'case_status_seaborn.png',
#  'categorical_data_analysis.ipynb',
#  'continent.csv',
#  'continents_df.csv',
#  'continents_seaborn.png',
#  'continent_df.csv',
#  'Data1.xlsx',
#  'education_df.csv',
#  'education_of_employee.csv',
#  'full_time_position.csv',
#  'graphs_matplotlib',
#  'graphs_seaborn',
#  'has_job_experience.csv',
#  'region_of_employment.csv',
#  'requires_job_training.csv',
#  'unit_of_wage.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'value_counts_df']

# %%
os.listdir(new_df1)
# Out:
# ['contact bank_graphs_seaborn.jpg',
#  'contact_bank_graphs_seaborn.jpg',
#  'default bank_graphs_seaborn.jpg',
#  'default_bank_graphs_seaborn.jpg',
#  'education bank_graphs_seaborn.jpg',
#  'education_bank_graphs_seaborn.jpg',
#  'housing bank_graphs_seaborn.jpg',
#  'housing_bank_graphs_seaborn.jpg',
#  'loan bank_graphs_seaborn.jpg',
#  'loan_bank_graphs_seaborn.jpg',
#  'marital bank_graphs_seaborn.jpg',
#  'marital_bank_graphs_seaborn.jpg',
#  'month bank_graphs_seaborn.jpg',
#  'month_bank_graphs_seaborn.jpg',
#  'poutcome bank_graphs_seaborn.jpg',
#  'poutcome_bank_graphs_seaborn.jpg',
#  'y bank_graphs_seaborn.jpg',
#  'y_bank_graphs_seaborn.jpg']

# %%
sns.countplot(x='marital',data=bank_df)
plt.title("bar chart")
plt.savefig(f"{new_df1}\{i}_value_counts_df_seaborn.jpg")
plt.show()
# Out:
# <string>:3: SyntaxWarning: invalid escape sequence '\{'
# <>:3: SyntaxWarning: invalid escape sequence '\{'
# <string>:3: SyntaxWarning: invalid escape sequence '\{'
# <>:3: SyntaxWarning: invalid escape sequence '\{'
# C:\Users\MAHESH\AppData\Local\Temp\ipykernel_10544\4145020556.py:3: SyntaxWarning: invalid escape sequence '\{'
#   plt.savefig(f"{new_df1}\{i}_value_counts_df_seaborn.jpg")

# %%
marital=bank_df['marital'].unique()
count=[]
for i in bank_df['marital'].unique():
    con=bank_df['marital']==i
    count.append(len(bank_df[con]))
cols=['marital_status','number of people']
marital_status_df=pd.DataFrame(zip(marital_status,count),columns=cols)
marital_status_df
# Out:
#   marital_status  number of people
# 0        married              2797
# 1         single              1196
# 2       divorced               528

# %%
import matplotlib.pyplot as plt
plt.bar('marital_status','number of people',data=marital_status_df)
plt.title("bar chart")
plt.show()
